# %% [markdown]
# 課題1：変数とデータ型

# %%
integer = 3
st = "Hello, Python!"
li = [1,2,3,4,5]

print(type(integer))
print(type(char))
print(type(li))

# %% [markdown]
# 課題2：条件分岐

# %%
a = float(input())
if a % 2 == 0:
   print("even")
else:
   print("odd")
# Out:
# 5
# odd

# %% [markdown]
# 課題3：ループ処理

# %%
a = list(range(1,100))
for i in a :
  if(i % 3 == 0) :
    print(i)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 42
# 45
# 48
# 51
# 54
# 57
# 60
# 63
# 66
# 69
# 72
# 75
# 78
# 81
# 84
# 87
# 90
# 93
# 96
# 99

# %% [markdown]
# 課題4：関数

# %%
def operator(a, b):
  plus = a + b
  minus = a - b
  times = a * b
  devided = a / b
  return([plus, minus, times, devided])

a,b=(float(x) for x in input().split())
print(operator(a, b))
# Out:
# 6 3
# 6.0 3.0
# [9.0, 3.0, 18.0, 2.0]

# %% [markdown]
# 課題5：リスト操作

# %%
a = [1, 2, 3, 4, 5]
b = list(map(lambda x : 2*x, a))
print(b)
# Out:
# [2, 4, 6, 8, 10]

# %% [markdown]
# 課題6：文字列操作

# %%
# while True:
#   s = input()
#   print(s.isalpha())
#   if(s.isalpha()):
#     break

s = input()
print(s.upper())
# Out:
# abc
# ABC
